# %%
import pandas as pd

# %%
import easygui

# %%
data_file = easygui.fileopenbox()
data_file
# Out:
# 'C:\\Users\\user\\Desktop\\the first semester of the fourth grade\\베이직 파이썬\\customers.csv'

# %%
data_raw = pd.read_csv(data_file, encoding='cp949')   # encoding ='utf8'
data_raw.head()
# Out:
#    조사번호                            조사지역 주구분        조사일자        시간대     X좌표  \
# 0  2544              신촌네거리 계룡건설 사옥 농협 앞  주중  2010-06-21  12시~13시까지  343099
# 1  2544              신촌네거리 계룡건설 사옥 농협 앞  주중  2010-06-21  19시~20시까지  343099
# 2  2544              신촌네거리 계룡건설 사옥 농협 앞  주말  2010-06-20  12시~13시까지  343099
# 3  2544              신촌네거리 계룡건설 사옥 농협 앞  주말  2010-06-20  19시~20시까지  343099
# 4  2545  계룡로에서 신촌네거리 진입우측 보쌈한판13,000원 앞  주중  2010-06-21  12시~13시까지  343121
#
#       Y좌표         행정구역명  날씨  남자10대  남자20대  남자30대  남자40대  남자50대  여자10대  여자20대  \
# 0  417482  대전광역시 서구 월평동  맑음      2     24     68     50     31      4     37
# 1  417482  대전광역시 서구 월평동  맑음     19     44     28     33     21     14     56
# 2  417482  대전광역시 서구 월평동  흐림     13     33     34     61     55     13     32
# 3  417482  대전광역시 서구 월평동  흐림     23     33     32    547    129     12     39
# 4  417343  대전광역시 서구 월평동  맑음      0      9     27     21      6      5     24
#
#    여자30대  여자40대  여자50대
# 0     64     44     26
# ...

# %%
df= pd.read_csv(data_file)   # encoding ='utf8'
df.head()
# Out:
#    customerNumber                customerName contactLastName  \
# 0             103           Atelier graphique         Schmitt
# 1             112          Signal Gift Stores            King
# 2             114  Australian Collectors, Co.        Ferguson
# 3             119           La Rochelle Gifts         Labrune
# 4             121          Baane Mini Imports      Bergulfsen
#
#   contactFirstName         phone                  addressLine1 addressLine2  \
# 0          Carine     40.32.2555                54, rue Royale          NaN
# 1             Jean    7025551838               8489 Strong St.          NaN
# 2            Peter  03 9520 4555             636 St Kilda Road      Level 3
# 3          Janine     40.67.8555  67, rue des Cinquante Otages          NaN
# 4           Jonas     07-98 9555        Erling Skakkes gate 78          NaN
#
#         city     state postalCode    country  salesRepEmployeeNumber  \
# ...

# %%
data_file = easygui.fileopenbox()
data_file
# Out:
# 'C:\\Users\\user\\Desktop\\the first semester of the fourth grade\\베이직 파이썬\\대전광역시_대학교 현황_20200623.csv'

# %%
data_raw= pd.read_csv(data_file, encoding='cp949')   # encoding ='utf8'
data_raw.head()
# Out:
#    연번           기관명 설립구분                   주소  \
# 0   1  건양대학교(대전캠퍼스)   사립    대전광역시 서구 관저동로 158
# 1   2         대전대학교   사립      대전광역시 동구 대학로 62
# 2   3       대전신학대학교   사립     대전광역시 대덕구 한남로 41
# 3   4         목원대학교   사립     대전광역시 서구 도안북로 88
# 4   5         배재대학교   사립  대전광역시 서구 배재로 155-40
#
#                                        홈페이지
# 0    https://www.konyang.ac.kr/kor.do#popup
# 1  http://www.dju.ac.kr/kor/html/intro3.htm
# 2                https://www.daejeon.ac.kr/
# 3                  http://www.mokwon.ac.kr/
# 4       http://www.pcu.ac.kr/uis/index.html

# %%
#url로 읽어오기
data_file = "http://youngho.iwinv.net/data/data_15060941.csv"
data_raw = pd.read_csv(data_file, encoding ='cp949')
data_raw.head()
# Out:
#    연번           기관명 설립구분                   주소  \
# 0   1  건양대학교(대전캠퍼스)   사립    대전광역시 서구 관저동로 158
# 1   2         대전대학교   사립      대전광역시 동구 대학로 62
# 2   3       대전신학대학교   사립     대전광역시 대덕구 한남로 41
# 3   4         목원대학교   사립     대전광역시 서구 도안북로 88
# 4   5         배재대학교   사립  대전광역시 서구 배재로 155-40
#
#                                        홈페이지
# 0    https://www.konyang.ac.kr/kor.do#popup
# 1  http://www.dju.ac.kr/kor/html/intro3.htm
# 2                https://www.daejeon.ac.kr/
# 3                  http://www.mokwon.ac.kr/
# 4       http://www.pcu.ac.kr/uis/index.html

# %%
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %%
customer.csv가지고 함

# %%
df.index
# Out:
# RangeIndex(start=0, stop=122, step=1)

# %%
#columns: 열이름
df.columns
# Out:
# Index(['customerNumber', 'customerName', 'contactLastName', 'contactFirstName',
#        'phone', 'addressLine1', 'addressLine2', 'city', 'state', 'postalCode',
#        'country', 'salesRepEmployeeNumber', 'creditLimit'],
#       dtype='object')

# %%
#shape: 행과 열의 수
df.shape
# Out:
# (122, 13)

# %%
#iloc: 정수 위치기반 인덱싱- 행
df.iloc[[0,1,2]]
# Out:
#    customerNumber                customerName contactLastName  \
# 0             103           Atelier graphique         Schmitt
# 1             112          Signal Gift Stores            King
# 2             114  Australian Collectors, Co.        Ferguson
#
#   contactFirstName         phone       addressLine1 addressLine2       city  \
# 0          Carine     40.32.2555     54, rue Royale          NaN     Nantes
# 1             Jean    7025551838    8489 Strong St.          NaN  Las Vegas
# 2            Peter  03 9520 4555  636 St Kilda Road      Level 3  Melbourne
#
#       state postalCode    country  salesRepEmployeeNumber  creditLimit
# 0       NaN      44000     France                  1370.0        21000
# 1        NV      83030        USA                  1166.0        71800
# 2  Victoria       3004  Australia                  1611.0       117300

# %%
#열뽑아오기
df.iloc[:,[3,4,5]]
# Out:
#     contactFirstName           phone                  addressLine1
# 0            Carine       40.32.2555                54, rue Royale
# 1               Jean      7025551838               8489 Strong St.
# 2              Peter    03 9520 4555             636 St Kilda Road
# 3            Janine       40.67.8555  67, rue des Cinquante Otages
# 4             Jonas       07-98 9555        Erling Skakkes gate 78
# ..               ...             ...                           ...
# 117             Rosa      2155559857             11328 Douglas Av.
# 118              Sue      4155554312             2793 Furth Circle
# 119          Thomas   (171) 555-7555               120 Hanover Sq.
# 120          Valarie      6175552555                6251 Ingle Ln.
# 121             Tony   +64 9 5555500            Arenales 1938 3'A'
#
# [122 rows x 3 columns]

# %%
#행&열  #시험나옴
df.iloc[[0,1,2],[3,4,5]]
# Out:
#   contactFirstName         phone       addressLine1
# 0          Carine     40.32.2555     54, rue Royale
# 1             Jean    7025551838    8489 Strong St.
# 2            Peter  03 9520 4555  636 St Kilda Road

# %%
df.iloc[:3,3:6]
# Out:
#   contactFirstName         phone       addressLine1
# 0          Carine     40.32.2555     54, rue Royale
# 1             Jean    7025551838    8489 Strong St.
# 2            Peter  03 9520 4555  636 St Kilda Road

# %%
#loc: lable 또는 조건을 이용한인덱싱  USA만 뽑아옴
df_usa = df.loc[df['country']=="USA"]
df_usa.shape
#36개가 usa데이터다, 36행
df_usa.head()

#데이터프레임의 특정 컬럼을 선택할때
#df['country'] 
#df.country
# Out:
#     customerNumber                  customerName contactLastName  \
# 1              112            Signal Gift Stores            King
# 5              124  Mini Gifts Distributors Ltd.          Nelson
# 8              129               Mini Wheels Co.          Murphy
# 9              131             Land of Toys Inc.             Lee
# 15             151            Muscle Machine Inc           Young
#
#    contactFirstName       phone               addressLine1 addressLine2  \
# 1              Jean  7025551838            8489 Strong St.          NaN
# 5             Susan  4155551450            5677 Strong St.          NaN
# 8             Julie  6505555787  5557 North Pendale Street          NaN
# 9              Kwai  2125557818    897 Long Airport Avenue          NaN
# 15             Jeff  2125557413          4092 Furth Circle    Suite 400
#
#              city state postalCode country  salesRepEmployeeNumber  \
# 1       Las Vegas    NV      83030     USA                  1166.0
# ...

# %% [markdown]
# # method

# %%
#head():처음부터 n번째 행
df_usa.head(5)
# Out:
#     customerNumber                  customerName contactLastName  \
# 1              112            Signal Gift Stores            King
# 5              124  Mini Gifts Distributors Ltd.          Nelson
# 8              129               Mini Wheels Co.          Murphy
# 9              131             Land of Toys Inc.             Lee
# 15             151            Muscle Machine Inc           Young
#
#    contactFirstName       phone               addressLine1 addressLine2  \
# 1              Jean  7025551838            8489 Strong St.          NaN
# 5             Susan  4155551450            5677 Strong St.          NaN
# 8             Julie  6505555787  5557 North Pendale Street          NaN
# 9              Kwai  2125557818    897 Long Airport Avenue          NaN
# 15             Jeff  2125557413          4092 Furth Circle    Suite 400
#
#              city state postalCode country  salesRepEmployeeNumber  \
# 1       Las Vegas    NV      83030     USA                  1166.0
# ...

# %%
#describe(): 변수(열)별 기술통계량   #숫자인 변수만 요약해줌
df_usa.describe()
df_usa.describe(include ="all")   #숫자가 아닌 범주형은 위 세가지, 숫자데이터는 mean부터 
#count: 중복포함 더한값    unique: 유일한 값(중복X)  
#top:가장많이 나온값       freq: 가장 많이 나온값이 몇개나 나왓는가
# Out:
#         customerNumber                  customerName contactLastName  \
# count        36.000000                            36              36
# unique             NaN                            36              23
# top                NaN  Motor Mint Distributors Inc.           Young
# freq               NaN                             1               4
# mean        298.000000                           NaN             NaN
# std         128.783983                           NaN             NaN
# min         112.000000                           NaN             NaN
# 25%         174.500000                           NaN             NaN
# 50%         319.500000                           NaN             NaN
# 75%         429.750000                           NaN             NaN
# max         495.000000                           NaN             NaN
#
#        contactFirstName       phone        addressLine1 addressLine2 city  \
# ...

# %%
#csv 저장
df_usa.to_csv('customer_USA.csv', index = False)

# %% [markdown]
# # 시각화

# %%
from matplotlib import pyplot as plt

# %%
#한글깨지지않도록 폰트 조정
plt.rcParams['font.family'] = 'Gulim'

# %%
tb = pd.crosstab(df['country'], 'Freq', colnames=[''])
tb
# Out:
#               Freq
# country
# Australia        5
# Austria          2
# Belgium          2
# Canada           3
# Denmark          2
# Finland          3
# France          12
# Germany         13
# Hong Kong        1
# Ireland          2
# Israel           1
# Italy            4
# Japan            2
# Netherlands      1
# New Zealand      4
# Norway           1
# Norway           2
# Philippines      1
# Poland           1
# Portugal         2
# Russia           1
# Singapore        3
# South Africa     1
# Spain            7
# Sweden           2
# Switzerland      3
# UK               5
# USA             36

# %%
#막대그래프
ax = tb.plot.bar()

# %%
#원그래프
ax = tb.plot.pie(y='Freq', legend =False, figsize = (6,6))

# %%
ax =df['creditLimit'].plot.hist()

# %%
ax = df['creditLimit'].plot.kde()

# %%
ax = df['creditLimit'].plot.box()

# %% [markdown]
# # 연습문제

# %% [markdown]
# 파일:타슈, encoding='cp949'

# %%
data_file = easygui.fileopenbox()
data_file
# Out:
# 'C:\\Users\\user\\Desktop\\the first semester of the fourth grade\\베이직 파이썬\\타슈_무인대여소_현황.csv'

# %%
dt= pd.read_csv(data_file, encoding='cp949')   # encoding ='utf8'
dt.head(10)
# Out:
#    번호               대여소명  거치대    구            주소         위도          경도   구역  \
# 0   1     무역전시관입구(택시승강장)   14  유성구       도룡동 3-8  36.374580  127.386131  1구역
# 1   2            대전컨벤션센터   20  유성구      도룡동 4-19  36.374389  127.392375  1구역
# 2   3             한밭수목원1   19   서구       만년동 396  36.369084  127.388451  1구역
# 3   4  초원아파트(104동 버스정류장)   12   서구       만년동 401  36.367945  127.379302  2구역
# 4   5    둔산대공원 입구(버스정류장)   13   서구  둔산2동 1521-10  36.364974  127.388856  1구역
# 5   6          백합네거리(농협)   12   서구      월평2동 266  36.362315  127.376427  2구역
# 6   7      정부청사 입구(대덕대로)   13   서구    둔산2동 920-2  36.362053  127.379704  1구역
# 7   8       정부청사 입구(샘머리)   12   서구     둔산2동 1518  36.361949  127.390433  1구역
# 8   9      황실아파트(성룡초등학교)   12   서구      월평2동 304  36.361655  127.374179  2구역
# 9  10   만년동 KBS 부근(기업은행)   12   서구       만년동 300  36.368632  127.379747  1구역
#
#    인터넷  CCTV 거치대.1   구조
# 0  NaN   1.0    평면  일자형
# 1  NaN   2.0    평면  일자형
# 2  NaN   2.0    평면  일자형
# ...

# %%
#기술통계량
dt.describe(include='all')
# Out:
#                번호       대여소명         거치대    구      주소          위도          경도  \
# count   261.00000        261  261.000000  261     261  261.000000  261.000000
# unique        NaN        261         NaN    5     257         NaN         NaN
# top           NaN  가람아파트(3동)         NaN  유성구  구성동 23         NaN         NaN
# freq          NaN          1         NaN   75       4         NaN         NaN
# mean    131.00000        NaN   13.153257  NaN     NaN   36.351671  127.389663
# std      75.48841        NaN    2.345101  NaN     NaN    0.035089    0.041459
# min       1.00000        NaN    8.000000  NaN     NaN   36.285012  127.297135
# 25%      66.00000        NaN   12.000000  NaN     NaN   36.325652  127.356048
# 50%     131.00000        NaN   13.000000  NaN     NaN   36.351114  127.388451
# 75%     196.00000        NaN   14.000000  NaN     NaN   36.367945  127.426281
# max     261.00000        NaN   28.000000  NaN     NaN   36.454126  127.465722
#
# ...

# %%
ax =dt['거치대'].plot.hist()

# %%
ax = dt['거치대'].plot.kde()

# %%
ax = dt['거치대'].plot.box()

# %%
tb = pd.crosstab(dt['구'], 'Freq', colnames=[''])
tb
# Out:
#      Freq
# 구
# 대덕구    38
# 동구     36
# 서구     73
# 유성구    75
# 중구     39

# %%
ax = tb.plot.bar()

# %%
ax = tb.plot.pie(y='Freq', legend =False, figsize = (6,6))
